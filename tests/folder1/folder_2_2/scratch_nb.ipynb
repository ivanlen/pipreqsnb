# %%
import glob
import os

# %%
path = './'

# %%
ipynb_files = [f for f in glob.glob(path + "**/*.ipynb", recursive=True)]

# %%
ipynb_files
# Out:
# ['./scratch_nb.ipynb',
#  './tests/autoencoder_test.ipynb',
#  './tests/jupyter_pipreqs.ipynb',
#  './tests/random_imports.ipynb',
#  './tests/folder1/twitter_scrapper.ipynb',
#  './tests/folder1/folder2/download_wiki_flags.ipynb']

# %%
test_folder = './tests/folder1/'
os.path.realpath(test_folder)
# Out:
# '/Users/ivanlengyel/coding_projects/pipreqsnb/tests/folder1'

# %%
os.path.basename(os.path.realpath(test_folder))
# Out:
# 'folder1'

# %%
for root, dirs, files in os.walk('./'):
#     print(root, dirs, files)
    print('DIRS:', dirs)
    for name in files:
            print(root, name)    
    print('__')
# Out:
# DIRS: ['.git', '.idea', '.ipynb_checkpoints', 'dist', 'pipreqsnb', 'pipreqsnb.egg-info', 'tests']
# ./ .DS_Store
# ./ .gitignore
# ./ LICENSE.txt
# ./ README.md
# ./ requirements.txt
# ./ scratch_nb.ipynb
# ./ setup.cfg
# ./ setup.py
# __
# DIRS: ['branches', 'hooks', 'info', 'logs', 'objects', 'refs']
# ./.git COMMIT_EDITMSG
# ./.git config
# ./.git description
# ./.git FETCH_HEAD
# ./.git HEAD
# ./.git index
# ./.git ORIG_HEAD
# __
# DIRS: []
# __
# DIRS: []
# ./.git/hooks applypatch-msg.sample
# ./.git/hooks commit-msg.sample
# ./.git/hooks post-update.sample
# ./.git/hooks pre-applypatch.sample
# ./.git/hooks pre-commit.sample
# ./.git/hooks pre-push.sample
# ./.git/hooks pre-rebase.sample
# ./.git/hooks pre-receive.sample
# ./.git/hooks prepare-commit-msg.sample
# ./.git/hooks update.sample
# __
# DIRS: []
# ./.git/info exclude
# __
# DIRS: ['refs']
# ./.git/logs HEAD
# __
# DIRS: ['heads', 'remotes']
# __
# DIRS: ['bugfix']
# ./.git/logs/refs/heads master
# __
# DIRS: []
# ./.git/logs/refs/heads/bugfix ignore
# ./.git/logs/refs/heads/bugfix setup
# __
# DIRS: ['origin']
# __
# DIRS: ['bugfix']
# ./.git/logs/refs/remotes/origin add-license-1
# ./.git/logs/refs/remotes/origin master
# __
# DIRS: []
# ./.git/logs/refs/remotes/origin/bugfix readme_typo
# ./.git/logs/refs/remotes/origin/bugfix setup
# __
# DIRS: ['04', '0d', '0e', '10', '11', '14', '1a', '1b', '1c', '1e', '1f', '21', '22', '25', '27', '29', '2f', '32', '33', '37', '39', '3b', '44', '4e', '4f', '50', '52', '5e', '66', '67', '6b', '6d', '77', '79', '7a', '7c', '8b', '8d', '8f', '96', '9d', 'a5', 'a7', 'b4', 'c5', 'c9', 'cc', 'd0', 'd7', 'd9', 'dd', 'de', 'e1', 'e4', 'e6', 'e8', 'e9', 'f2', 'f8', 'info', 'pack']
# __
# DIRS: []
# ./.git/objects/04 1eee9e357451f21d9a4f2922ecdb6bc9e293a6
# __
# DIRS: []
# ./.git/objects/0d 99c6d480237d6e71b640ca8ed94b5ae76ef356
# __
# DIRS: []
# ./.git/objects/0e 3436e4d90802fb163db716ed14f1806be29461
# __
# DIRS: []
# ./.git/objects/10 11d6ab3ccc103c741efa597a381879f0eccb29
# __
# DIRS: []
# ./.git/objects/11 68dee575adc78e0cbb195a434e076d71b387d8
# __
# DIRS: []
# ./.git/objects/14 4264216a187fc1dd8e5870a04ef739a9ebcd3f
# __
# DIRS: []
# ./.git/objects/1a 8ce7523136225eb59c69efb9679467046c160b
# __
# DIRS: []
# ./.git/objects/1b 0a4918f35741ebed771d3f86265a0d8e44bea5
# __
# DIRS: []
# ./.git/objects/1c 28c301acd719f1a45e388c1de67f87fb433264
# ./.git/objects/1c b0200bcbc1799e035dc45b0ddc3b77bac5dcd8
# __
# DIRS: []
# ./.git/objects/1e e310ff6bb8608f5d1f7b2de171eef4252fea99
# __
# DIRS: []
# ./.git/objects/1f a4ecdcda1f30982e0f68d8f20d90834c7fdbec
# __
# DIRS: []
# ./.git/objects/21 5b66e736c5b1f622ac08bc9d91b4d2c16a6df0
# __
# DIRS: []
# ./.git/objects/22 4a77957f5db48dfa25c8bb4a35f535202da203
# __
# DIRS: []
# ./.git/objects/25 79fbcf49900f2780138cd83002d6a07f72325a
# __
# DIRS: []
# ./.git/objects/27 4b06466563916299ccc9e15e2bd3a4a61bd815
# __
# DIRS: []
# ./.git/objects/29 0adcab6fb271be423dcd920ca46c123b27975c
# __
# DIRS: []
# ./.git/objects/2f aef78747fe16d7b575ea94f78cacd449809b44
# __
# DIRS: []
# ./.git/objects/32 843dbe2a918c627a11f5e6e7a775bf763f60cd
# __
# DIRS: []
# ./.git/objects/33 21e3e2f23eafa8486565457768ebf5b15c94b7
# __
# DIRS: []
# ./.git/objects/37 19c755e008002111c82759c2734e819291dbc6
# __
# DIRS: []
# ./.git/objects/39 591259bf929c1a885a86d9bdd97aa469d74f66
# ./.git/objects/39 d3f156b4df6e56d50251d4db3040a00759dcb3
# __
# DIRS: []
# ./.git/objects/3b f784f34035599db847feded4f5995ff339b027
# __
# DIRS: []
# ./.git/objects/44 8474b40b7c1a859edfae202861b603fc8e36b2
# __
# DIRS: []
# ./.git/objects/4e 8685175cd3e492d13685bdabf8804bdccbcf13
# __
# DIRS: []
# ./.git/objects/4f 6228a2f35b3dd12a7ebd64108ef709a16b82b7
# __
# DIRS: []
# ./.git/objects/50 c1812156813ebca65d7d5048e0ba33ae60ca0d
# __
# DIRS: []
# ./.git/objects/52 c7f2898bbfd9d6f76a89ca19a2e3c616e55a27
# __
# DIRS: []
# ./.git/objects/5e ba93eb8c290537a8c22468f3172159f0c0cb40
# __
# DIRS: []
# ./.git/objects/66 eae9015c1a61402a8927883b1f727a9c9c7ef2
# __
# DIRS: []
# ./.git/objects/67 781f8c47231dd219fa5118f0c66638f09f4d42
# ./.git/objects/67 fee3534ef40ff44ef0a5e997a87c506e211858
# __
# DIRS: []
# ./.git/objects/6b e8617dd164846faae50b563a28f3d3aae53325
# __
# DIRS: []
# ./.git/objects/6d b1a4b8367fcdde91ef4d8abc4378c9bbd4b394
# ./.git/objects/6d c4a21ea87a6572bc99e6a659be8935a8df5f55
# __
# DIRS: []
# ./.git/objects/77 f1938dafe424c7673e4e4c97fe58cf0644bcab
# __
# DIRS: []
# ./.git/objects/79 4ab34096be8783e70ef37006306503e0ae9bb7
# __
# DIRS: []
# ./.git/objects/7a af5249ab7b2fb07b0a737e79fe945c20a8d17c
# __
# DIRS: []
# ./.git/objects/7c f758143e6810ff160ffc92ee3fd7e0b0a3e0ca
# __
# DIRS: []
# ./.git/objects/8b 34d035d4724874b649b6a7ca6381760c26f7b6
# __
# DIRS: []
# ./.git/objects/8d 2eecc10c96386aecc3f5273c4e676d6828d9f4
# __
# DIRS: []
# ./.git/objects/8f dc5dac66adf49826bce160378ad1f7c2d931e8
# __
# DIRS: []
# ./.git/objects/96 335b45429db13401e76798dd0b3ed6d6c8efec
# __
# DIRS: []
# ./.git/objects/9d 33f87a1ff599d71e3f724811bea8186772dd39
# __
# DIRS: []
# ./.git/objects/a5 c6df7d50eb138feede7c022e51bc8486d86f5d
# __
# DIRS: []
# ./.git/objects/a7 9ff2f1a712f68ed04d99fa30556d11c297c4f9
# __
# DIRS: []
# ./.git/objects/b4 3cb176c3ab118bf04f265eae6862f7ed2032c5
# __
# DIRS: []
# ./.git/objects/c5 2237f414ba5ba0af522e29a4cd49277c1d3842
# __
# DIRS: []
# ./.git/objects/c9 bd744e382a98f535f2963ed85019841f4a8c1b
# __
# DIRS: []
# ./.git/objects/cc a6314bbc19f0ad5d7f8885212fde279f8d6889
# __
# DIRS: []
# ./.git/objects/d0 c90c6b96641811a1fd1f429a69a9598dc69947
# __
# DIRS: []
# ./.git/objects/d7 3eb47b8e23bc8ad1f18743a3f7566c9c43b9ba
# __
# DIRS: []
# ./.git/objects/d9 afa86261ec0e47fa4ad880b3b1121357f59510
# __
# DIRS: []
# ./.git/objects/dd 15ee52acb8038d672ec5fb117f48456633470b
# __
# DIRS: []
# ./.git/objects/de 72724ea3dbcc785dfa23d62a03120346f3a239
# __
# DIRS: []
# ./.git/objects/e1 beaf25d57ab21c1f37756fdde31d5ddfe48107
# __
# DIRS: []
# ./.git/objects/e4 b3c095c229f6565d44569f969b65e0f61af227
# __
# DIRS: []
# ./.git/objects/e6 9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# __
# DIRS: []
# ./.git/objects/e8 def3327cbe538b46c69e0d510d5a807291bc15
# __
# DIRS: []
# ./.git/objects/e9 5753ec4c50f5ad1a149be372626f006a571fa8
# __
# DIRS: []
# ./.git/objects/f2 c36ec19725c368ff229ff0c0fa3b286921a9ad
# __
# DIRS: []
# ./.git/objects/f8 94f070bc12399a0b6bd3070b24d23e8643c066
# __
# DIRS: []
# __
# DIRS: []
# __
# DIRS: ['heads', 'remotes', 'tags']
# __
# DIRS: ['bugfix']
# ./.git/refs/heads master
# __
# DIRS: []
# ./.git/refs/heads/bugfix ignore
# ./.git/refs/heads/bugfix setup
# __
# DIRS: ['origin']
# __
# DIRS: ['bugfix']
# ./.git/refs/remotes/origin add-license-1
# ./.git/refs/remotes/origin master
# __
# DIRS: []
# ./.git/refs/remotes/origin/bugfix readme_typo
# ./.git/refs/remotes/origin/bugfix setup
# __
# DIRS: []
# __
# DIRS: []
# ./.idea encodings.xml
# ./.idea misc.xml
# ./.idea modules.xml
# ./.idea pipreqsnb.iml
# ./.idea vcs.xml
# ./.idea workspace.xml
# __
# DIRS: []
# ./.ipynb_checkpoints scratch_nb-checkpoint.ipynb
# __
# DIRS: []
# ./dist pipreqsnb-0.1.1.tar.gz
# ./dist pipreqsnb-0.1.2.tar.gz
# __
# DIRS: ['__pycache__']
# ./pipreqsnb .DS_Store
# ./pipreqsnb __init__.py
# ./pipreqsnb pipreqsnb.py
# __
# DIRS: []
# ./pipreqsnb/__pycache__ __init__.cpython-37.pyc
# ./pipreqsnb/__pycache__ pipreqsnb.cpython-37.pyc
# __
# DIRS: []
# ./pipreqsnb.egg-info dependency_links.txt
# ./pipreqsnb.egg-info entry_points.txt
# ./pipreqsnb.egg-info not-zip-safe
# ./pipreqsnb.egg-info PKG-INFO
# ./pipreqsnb.egg-info requires.txt
# ./pipreqsnb.egg-info SOURCES.txt
# ./pipreqsnb.egg-info top_level.txt
# __
# DIRS: ['folder1']
# ./tests .DS_Store
# ./tests autoencoder_test.ipynb
# ./tests jupyter_pipreqs.ipynb
# ./tests random_imports.ipynb
# __
# DIRS: ['folder2']
# ./tests/folder1 .DS_Store
# ./tests/folder1 twitter_scrapper.ipynb
# __
# DIRS: []
# ./tests/folder1/folder2 download_wiki_flags.ipynb
# __
